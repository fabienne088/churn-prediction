# %%
# Data Processing
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Data Preprocessing
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Imbalanced Data
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTENC

# Modelling
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
# from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree

# Evaluation
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, roc_auc_score

# %%
cleaned_churners = pd.read_csv('churners_clean_df.csv')

# %%
# Replace Unknown values by nan in categorical data
#cleaned_churners.replace('Unknown', np.nan, inplace=True)

# %%
# Get the unique values of categorical columns
cat_cols = cleaned_churners.select_dtypes(include = 'object').columns.tolist()
for col in cat_cols:
    unique_values = cleaned_churners[col].unique()
    print(f"Unique values in '{col}' are: {unique_values}")
# Out:
# Unique values in 'Attrition_Flag' are: ['Existing Customer' 'Attrited Customer']
# Unique values in 'Gender' are: ['M' 'F']
# Unique values in 'Education_Level' are: ['Graduate' 'Uneducated' 'Doctorate' 'Unknown' 'High School' 'College'
#  'Post-Graduate']
# Unique values in 'Marital_Status' are: ['Married' 'Unknown' 'Divorced' 'Single']
# Unique values in 'Income_Category' are: ['$40K - $60K' '$120K +' 'Less than $40K' '$60K - $80K' '$80K - $120K']
# Unique values in 'Card_Category' are: ['Blue' 'Gold' 'Silver' 'Platinum']

# %% [markdown]
# ### Imbalanced data

# %%
X = cleaned_churners.drop('Attrition_Flag', axis=1)
y = cleaned_churners['Attrition_Flag']

# %%
print (type(X))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Class distribution

# %%
y.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    6970
# Attrited Customer    1365
# Name: count, dtype: int64

# %%
y.value_counts().plot.pie(autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Random Undersampling <br>
# 'not minority' = resample all classes but the minority class

# %%
rus = RandomUnderSampler(sampling_strategy=1) # Numerical value
# rus = RandomUnderSampler(sampling_strategy="not minority") # String
X_rus, y_rus = rus.fit_resample(X, y)

ax = y_rus.value_counts().plot.pie(autopct='%.2f')
_ = ax.set_title("Under-sampling")

# Class distribution after resampling
y_rus.value_counts()
# Out:
# Attrition_Flag
# Attrited Customer    1365
# Existing Customer    1365
# Name: count, dtype: int64

# %% [markdown]
# Random Oversampling <br>
# "not majority" = resample all classes but the majority class

# %%
# ros = RandomOverSampler(sampling_strategy=1) # Float
ros = RandomOverSampler(sampling_strategy="not majority") # String
X_ros, y_ros = ros.fit_resample(X, y)

ax = y_ros.value_counts().plot.pie(autopct='%.2f')
_ = ax.set_title("Over-sampling")

y_ros.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    6970
# Attrited Customer    6970
# Name: count, dtype: int64

# %% [markdown]
# SMOTENC: SMOTE with categorical features

# %%
display(X.head())
cat = X.select_dtypes(include = 'object').columns
# get index of cat columns
index = X.columns.get_indexer(cat)
print(index)
# Out:
#    Customer_Age Gender  Dependent_count Education_Level Marital_Status  \
# 0            44      M                2        Graduate        Married
# 1            42      M                5      Uneducated        Unknown
# 2            57      F                2        Graduate        Married
# 3            47      M                1       Doctorate       Divorced
# 4            62      F                0        Graduate        Married
#
#   Income_Category Card_Category  Months_on_book  Total_Relationship_Count  \
# 0     $40K - $60K          Blue              36                         3
# 1         $120K +          Blue              31                         5
# 2  Less than $40K          Blue              48                         5
# 3     $60K - $80K          Blue              42                         5
# 4  Less than $40K          Blue              49                         2
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0                       1                      2        4010.0
# 1                       3                      2        6748.0
# 2                       2                      2        2436.0
# 3                       2                      0       20979.0
# 4                       3                      3        1438.3
#
#    Total_Revolving_Bal  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                 1247                 1.376             1088              24
# 1                 1467                 0.831             1201              42
# 2                  680                 1.190             1570              29
# 3                 1800                 0.906             1178              27
# 4                    0                 1.047              692              16
#
#    Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                0.846                  0.311
# 1                0.680                  0.217
# 2                0.611                  0.279
# 3                0.929                  0.086
# 4                0.600                  0.000
# [1 3 4 5 6]

# %%
sm = SMOTENC(sampling_strategy="minority", categorical_features=[1,3,4,5,6])
X_sm, y_sm = sm.fit_resample(X, y)

# %% [markdown]
# Training

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, random_state=42, test_size=0.3)

# %%
num_cols = X_train.select_dtypes(exclude='object').columns
cat_cols = X_train.select_dtypes(include='object').columns

# %%
# Define preprocessing steps for numeric and categorical data
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(missing_values='Unknown', strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Combine preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_cols),
        ('cat', categorical_transformer, cat_cols)
    ],
    remainder='drop',
    n_jobs=-1,
    verbose=True)

# %%
# Select the columns with categorical values
categorical_cols = X_train.select_dtypes(include=['object']).columns.tolist()
print("columns_to_encode =", categorical_cols)

# Initialize the encoder
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoded_array = encoder.fit_transform(X_train[categorical_cols])

# Convert the encoded array into a DataFrame
encoded_df = pd.DataFrame(encoded_array, columns=encoder.get_feature_names_out(categorical_cols))

# Concatenate the encoded DataFrame with the original DataFrame
result_df = pd.concat([X_train, encoded_df], axis=1)

# Drop the original categorical columns if needed
result_df.drop(columns = categorical_cols, axis=1, inplace=True) 

print(result_df.info())
result_df.isna().sum().sort_values(ascending=False)
# Out:
# columns_to_encode = ['Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category']
# <class 'pandas.core.frame.DataFrame'>
# Index: 12717 entries, 9436 to 9757
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Customer_Age                    9758 non-null   float64
#  1   Dependent_count                 9758 non-null   float64
#  2   Months_on_book                  9758 non-null   float64
#  3   Total_Relationship_Count        9758 non-null   float64
#  4   Months_Inactive_12_mon          9758 non-null   float64
#  5   Contacts_Count_12_mon           9758 non-null   float64
#  6   Credit_Limit                    9758 non-null   float64
#  7   Total_Revolving_Bal             9758 non-null   float64
#  8   Total_Amt_Chng_Q4_Q1            9758 non-null   float64
#  9   Total_Trans_Amt                 9758 non-null   float64
#  10  Total_Trans_Ct                  9758 non-null   float64
#  11  Total_Ct_Chng_Q4_Q1             9758 non-null   float64
#  12  Avg_Utilization_Ratio           9758 non-null   float64
#  13  Gender_F                        9758 non-null   float64
#  14  Gender_M                        9758 non-null   float64
#  15  Education_Level_College         9758 non-null   float64
#  16  Education_Level_Doctorate       9758 non-null   float64
#  17  Education_Level_Graduate        9758 non-null   float64
#  18  Education_Level_High School     9758 non-null   float64
#  19  Education_Level_Post-Graduate   9758 non-null   float64
#  20  Education_Level_Uneducated      9758 non-null   float64
#  21  Education_Level_Unknown         9758 non-null   float64
#  22  Marital_Status_Divorced         9758 non-null   float64
#  23  Marital_Status_Married          9758 non-null   float64
#  24  Marital_Status_Single           9758 non-null   float64
#  25  Marital_Status_Unknown          9758 non-null   float64
#  26  Income_Category_$120K +         9758 non-null   float64
#  27  Income_Category_$40K - $60K     9758 non-null   float64
#  28  Income_Category_$60K - $80K     9758 non-null   float64
#  29  Income_Category_$80K - $120K    9758 non-null   float64
#  30  Income_Category_Less than $40K  9758 non-null   float64
#  31  Card_Category_Blue              9758 non-null   float64
#  32  Card_Category_Gold              9758 non-null   float64
#  33  Card_Category_Platinum          9758 non-null   float64
#  34  Card_Category_Silver            9758 non-null   float64
# dtypes: float64(35)
# memory usage: 3.5 MB
# None
# Customer_Age                      2959
# Income_Category_$120K +           2959
# Education_Level_Uneducated        2959
# Education_Level_Unknown           2959
# Marital_Status_Divorced           2959
# Marital_Status_Married            2959
# Marital_Status_Single             2959
# Marital_Status_Unknown            2959
# Income_Category_$40K - $60K       2959
# Education_Level_High School       2959
# Income_Category_$60K - $80K       2959
# Income_Category_$80K - $120K      2959
# Income_Category_Less than $40K    2959
# Card_Category_Blue                2959
# Card_Category_Gold                2959
# Card_Category_Platinum            2959
# Education_Level_Post-Graduate     2959
# Education_Level_Graduate          2959
# Dependent_count                   2959
# Total_Amt_Chng_Q4_Q1              2959
# Months_on_book                    2959
# Total_Relationship_Count          2959
# Months_Inactive_12_mon            2959
# Contacts_Count_12_mon             2959
# Credit_Limit                      2959
# Total_Revolving_Bal               2959
# Total_Trans_Amt                   2959
# Education_Level_Doctorate         2959
# Total_Trans_Ct                    2959
# Total_Ct_Chng_Q4_Q1               2959
# Avg_Utilization_Ratio             2959
# Gender_F                          2959
# Gender_M                          2959
# Education_Level_College           2959
# Card_Category_Silver              2959
# dtype: int64

# %%
# Fit and transform the preprocesing steps on the training data
preprocessed = preprocessor.fit(X_train)

X_train_processed = preprocessed.transform(X_train)
X_test_processed = preprocessed.transform(X_test)

# %% [markdown]
# Classifiers: KNN Classifier

# %%
# KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_processed, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Make predictions
y_pred = knn.predict(X_test_processed)

# Evaluate the model
print(round(knn.score(X_test_processed, y_test),2))

# Confusion matrix
confusion_matrix(y_test, y_pred)
crosstab = pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
display(crosstab)

# Generate classification report
report = classification_report(y_test, y_pred, zero_division=1)
print(f"Classification Report:\n{classification_report(y_test, y_pred, zero_division=1)}")
# Out:
# 0.92
# Predicted          Attrited Customer  Existing Customer   All
# Actual
# Attrited Customer               2049                 45  2094
# Existing Customer                277               1811  2088
# All                             2326               1856  4182
# Classification Report:
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.88      0.98      0.93      2094
# Existing Customer       0.98      0.87      0.92      2088
#
#          accuracy                           0.92      4182
#         macro avg       0.93      0.92      0.92      4182
#      weighted avg       0.93      0.92      0.92      4182

# %% [markdown]
# Classifiers: Random Forest

# %%
# Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_processed, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions
y_pred = rf_model.predict(X_test_processed)
y_prob = rf_model.predict_proba(X_test_processed)

# Evaluate the model
print(round(rf_model.score(X_test_processed, y_test),2))
print(round(roc_auc_score(y_test, y_prob[:,1]),2))

# Confusion matrix
confusion_matrix(y_test, y_pred)
crosstab = pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
display(crosstab)
# Out:
# 0.97
# 1.0
# Predicted          Attrited Customer  Existing Customer   All
# Actual
# Attrited Customer               2049                 45  2094
# Existing Customer                 74               2014  2088
# All                             2123               2059  4182

# %%
# Generate classification report
report = classification_report(y_test, y_pred, zero_division=1)
print(f"Classification Report:\n{classification_report(y_test, y_pred, zero_division=1)}")
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.97      0.98      0.97      2094
# Existing Customer       0.98      0.96      0.97      2088
#
#          accuracy                           0.97      4182
#         macro avg       0.97      0.97      0.97      4182
#      weighted avg       0.97      0.97      0.97      4182

# %% [markdown]
# Classifiers: Decision Tree

# %%
# Train Decision Tree on Classification Task
dt_clf = DecisionTreeClassifier(criterion='entropy', random_state=42)
dt_clf.fit(X_train_processed, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
# Print Text Representation
text_representation = tree.export_text(dt_clf)
print(text_representation)
# Out:
# |--- feature_10 <= -0.02
# |   |--- feature_7 <= -0.39
# |   |   |--- feature_3 <= -0.63
# |   |   |   |--- feature_11 <= 2.54
# |   |   |   |   |--- feature_12 <= 0.58
# |   |   |   |   |   |--- feature_1 <= 1.88
# |   |   |   |   |   |   |--- feature_24 <= 0.50
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_24 >  0.50
# |   |   |   |   |   |   |   |--- feature_6 <= 0.75
# |   |   |   |   |   |   |   |   |--- feature_6 <= 0.66
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_6 >  0.66
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_6 >  0.75
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |--- feature_1 >  1.88
# |   |   |   |   |   |   |--- feature_8 <= -0.49
# |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_8 >  -0.49
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |--- feature_12 >  0.58
# |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |--- feature_11 >  2.54
# |   |   |   |   |--- class: Existing Customer
# |   |   |--- feature_3 >  -0.63
# |   |   |   |--- feature_9 <= -0.64
# |   |   |   |   |--- feature_11 <= -0.19
# |   |   |   |   |   |--- feature_4 <= -0.97
# |   |   |   |   |   |   |--- feature_8 <= -0.19
# |   |   |   |   |   |   |   |--- feature_5 <= -1.00
# |   |   |   |   |   |   |   |   |--- feature_27 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_27 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_5 >  -1.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.03
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.03
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= -0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  -0.04
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_8 >  -0.19
# |   |   |   |   |   |   |   |--- feature_9 <= -0.90
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1.48
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_2 >  1.48
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_9 >  -0.90
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_4 >  -0.97
# |   |   |   |   |   |   |--- feature_3 <= 1.33
# |   |   |   |   |   |   |   |--- feature_5 <= -2.02
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_5 >  -2.02
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.64
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.68
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.68
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.64
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_3 >  1.33
# |   |   |   |   |   |   |   |--- feature_9 <= -1.01
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_9 >  -1.01
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.68
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= -0.59
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  -0.59
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.68
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |--- feature_11 >  -0.19
# |   |   |   |   |   |--- feature_9 <= -1.00
# |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |--- feature_9 >  -1.00
# |   |   |   |   |   |   |--- feature_8 <= -0.65
# |   |   |   |   |   |   |   |--- feature_9 <= -0.73
# |   |   |   |   |   |   |   |   |--- feature_10 <= -0.82
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_10 >  -0.82
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_9 >  -0.73
# |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_8 >  -0.65
# |   |   |   |   |   |   |   |--- feature_11 <= 0.53
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.06
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.06
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_11 >  0.53
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |--- feature_9 >  -0.64
# |   |   |   |   |--- feature_10 <= -0.35
# |   |   |   |   |   |--- feature_0 <= -2.33
# |   |   |   |   |   |   |--- feature_11 <= -0.26
# |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_11 >  -0.26
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |--- feature_0 >  -2.33
# |   |   |   |   |   |   |--- feature_9 <= -0.62
# |   |   |   |   |   |   |   |--- feature_9 <= -0.63
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_9 >  -0.63
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.62
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.62
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= -0.56
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  -0.56
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_9 >  -0.62
# |   |   |   |   |   |   |   |--- feature_5 <= -2.02
# |   |   |   |   |   |   |   |   |--- feature_6 <= -0.65
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_6 >  -0.65
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_5 >  -2.02
# |   |   |   |   |   |   |   |   |--- feature_3 <= 1.33
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_3 >  1.33
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.75
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.51
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.75
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |--- feature_10 >  -0.35
# |   |   |   |   |   |--- feature_9 <= -0.27
# |   |   |   |   |   |   |--- feature_0 <= -1.22
# |   |   |   |   |   |   |   |--- feature_13 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_13 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.42
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.42
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_0 >  -1.22
# |   |   |   |   |   |   |   |--- feature_6 <= -0.54
# |   |   |   |   |   |   |   |   |--- feature_26 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_26 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.74
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.74
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_6 >  -0.54
# |   |   |   |   |   |   |   |   |--- feature_0 <= -0.80
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_0 >  -0.80
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.34
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= -0.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  -0.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.34
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_9 >  -0.27
# |   |   |   |   |   |   |--- feature_9 <= 0.24
# |   |   |   |   |   |   |   |--- feature_11 <= 0.04
# |   |   |   |   |   |   |   |   |--- feature_6 <= 0.89
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= -0.04
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 2.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  2.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  -0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_6 >  0.89
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_11 >  0.04
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_9 >  0.24
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |--- feature_7 >  -0.39
# |   |   |--- feature_3 <= -0.63
# |   |   |   |--- feature_5 <= -2.02
# |   |   |   |   |--- feature_11 <= -0.62
# |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |--- feature_11 >  -0.62
# |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |--- feature_5 >  -2.02
# |   |   |   |   |--- feature_7 <= 1.26
# |   |   |   |   |   |--- feature_7 <= 0.70
# |   |   |   |   |   |   |--- feature_17 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 0.45
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.79
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.27
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.79
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.45
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_0 >  0.45
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_17 >  0.50
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |--- feature_7 >  0.70
# |   |   |   |   |   |   |--- feature_11 <= -1.07
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_11 >  -1.07
# |   |   |   |   |   |   |   |--- feature_28 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.85
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= -0.66
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  -0.66
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.85
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 2.52
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= -0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  -0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  2.52
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_28 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.11
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.11
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |--- feature_7 >  1.26
# |   |   |   |   |   |--- class: Attrited Customer
# |   |   |--- feature_3 >  -0.63
# |   |   |   |--- feature_9 <= -0.65
# |   |   |   |   |--- feature_9 <= -1.00
# |   |   |   |   |   |--- feature_11 <= 0.36
# |   |   |   |   |   |   |--- feature_25 <= 0.50
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_25 >  0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 0.03
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_3 >  0.03
# |   |   |   |   |   |   |   |   |--- feature_0 <= -0.39
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_0 >  -0.39
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_11 >  0.36
# |   |   |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 0.68
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_3 >  0.68
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |--- feature_9 >  -1.00
# |   |   |   |   |   |--- feature_8 <= -0.83
# |   |   |   |   |   |   |--- feature_9 <= -0.77
# |   |   |   |   |   |   |   |--- feature_11 <= -1.26
# |   |   |   |   |   |   |   |   |--- feature_12 <= 2.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_12 >  2.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.05
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.05
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_11 >  -1.26
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.03
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= -0.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= -0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  -0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  -0.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 2.59
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  2.59
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.03
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_9 >  -0.77
# |   |   |   |   |   |   |   |--- feature_0 <= 1.14
# |   |   |   |   |   |   |   |   |--- feature_8 <= -1.55
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= -1.36
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  -1.36
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_8 >  -1.55
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.75
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.75
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.66
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_0 >  1.14
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.65
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.65
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 0.31
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  0.31
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_8 >  -0.83
# |   |   |   |   |   |   |--- feature_11 <= 0.18
# |   |   |   |   |   |   |   |--- feature_9 <= -0.94
# |   |   |   |   |   |   |   |   |--- feature_12 <= -0.15
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= -0.55
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  -0.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_12 >  -0.15
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.62
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.62
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= -0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  -0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_9 >  -0.94
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.17
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.72
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= -0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  -0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.72
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= -0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  -0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.17
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_11 >  0.18
# |   |   |   |   |   |   |   |--- feature_4 <= -2.16
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_4 >  -2.16
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |--- feature_9 >  -0.65
# |   |   |   |   |--- feature_11 <= 0.66
# |   |   |   |   |   |--- feature_0 <= -1.22
# |   |   |   |   |   |   |--- feature_8 <= 0.27
# |   |   |   |   |   |   |   |--- feature_2 <= -1.70
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.03
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.40
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.40
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.03
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_2 >  -1.70
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.60
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.60
# |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= -1.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  -1.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= -0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  -0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_8 >  0.27
# |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_0 >  -1.22
# |   |   |   |   |   |   |--- feature_10 <= -0.40
# |   |   |   |   |   |   |   |--- feature_9 <= -0.52
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.28
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= -0.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  -0.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.28
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= -1.21
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  -1.21
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 2.31
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  2.31
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_9 >  -0.52
# |   |   |   |   |   |   |   |   |--- feature_26 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= -1.77
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  -1.77
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_26 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.62
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.62
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_10 >  -0.40
# |   |   |   |   |   |   |   |--- feature_7 <= 1.44
# |   |   |   |   |   |   |   |   |--- feature_3 <= 1.33
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.23
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.23
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= -0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  -0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_3 >  1.33
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -1.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= -0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  -0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -1.35
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_7 >  1.44
# |   |   |   |   |   |   |   |   |--- feature_5 <= 1.05
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_5 >  1.05
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.56
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.56
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  1.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |--- feature_11 >  0.66
# |   |   |   |   |   |--- feature_9 <= 1.10
# |   |   |   |   |   |   |--- feature_11 <= 1.54
# |   |   |   |   |   |   |   |--- feature_7 <= 0.83
# |   |   |   |   |   |   |   |   |--- feature_7 <= -0.12
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= -0.59
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  -0.59
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_7 >  -0.12
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_7 >  0.83
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.70
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.54
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= -0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  -0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.70
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_11 >  1.54
# |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_9 >  1.10
# |   |   |   |   |   |   |--- class: Attrited Customer
# |--- feature_10 >  -0.02
# |   |--- feature_9 <= 0.57
# |   |   |--- feature_10 <= 0.35
# |   |   |   |--- feature_9 <= 0.31
# |   |   |   |   |--- feature_9 <= -0.28
# |   |   |   |   |   |--- feature_8 <= 0.66
# |   |   |   |   |   |   |--- feature_7 <= -0.47
# |   |   |   |   |   |   |   |--- feature_6 <= -0.38
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.53
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.53
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1.33
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  1.33
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_6 >  -0.38
# |   |   |   |   |   |   |   |   |--- feature_7 <= -0.95
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.23
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.23
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_7 >  -0.95
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_7 >  -0.47
# |   |   |   |   |   |   |   |--- feature_7 <= 1.60
# |   |   |   |   |   |   |   |   |--- feature_6 <= -0.70
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_6 >  -0.70
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -1.13
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= -1.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  -1.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -1.13
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_7 >  1.60
# |   |   |   |   |   |   |   |   |--- feature_8 <= -0.75
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_8 >  -0.75
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.45
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.45
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |--- feature_8 >  0.66
# |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |--- feature_9 >  -0.28
# |   |   |   |   |   |--- feature_11 <= -0.03
# |   |   |   |   |   |   |--- feature_8 <= 0.79
# |   |   |   |   |   |   |   |--- feature_3 <= -1.28
# |   |   |   |   |   |   |   |   |--- feature_4 <= -0.97
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_4 >  -0.97
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_3 >  -1.28
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_8 >  0.79
# |   |   |   |   |   |   |   |--- feature_22 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.68
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.68
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_22 >  0.50
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_11 >  -0.03
# |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |--- feature_9 >  0.31
# |   |   |   |   |--- feature_11 <= 0.18
# |   |   |   |   |   |--- feature_8 <= 0.37
# |   |   |   |   |   |   |--- feature_3 <= -0.63
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_3 >  -0.63
# |   |   |   |   |   |   |   |--- feature_1 <= 1.88
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_1 >  1.88
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |--- feature_8 >  0.37
# |   |   |   |   |   |   |--- feature_8 <= 1.08
# |   |   |   |   |   |   |   |--- feature_9 <= 0.41
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_9 >  0.41
# |   |   |   |   |   |   |   |   |--- feature_11 <= -0.60
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_11 >  -0.60
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_8 >  1.08
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |--- feature_11 >  0.18
# |   |   |   |   |   |--- feature_9 <= 0.47
# |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_9 >  0.47
# |   |   |   |   |   |   |--- feature_7 <= -0.51
# |   |   |   |   |   |   |   |--- feature_9 <= 0.52
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_9 >  0.52
# |   |   |   |   |   |   |   |   |--- feature_18 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_18 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_7 >  -0.51
# |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |--- feature_10 >  0.35
# |   |   |   |--- feature_10 <= 0.59
# |   |   |   |   |--- feature_11 <= 0.04
# |   |   |   |   |   |--- feature_8 <= 1.41
# |   |   |   |   |   |   |--- feature_9 <= -0.40
# |   |   |   |   |   |   |   |--- feature_11 <= -0.41
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_11 >  -0.41
# |   |   |   |   |   |   |   |   |--- feature_0 <= -1.22
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_0 >  -1.22
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_9 >  -0.40
# |   |   |   |   |   |   |   |--- feature_3 <= -1.28
# |   |   |   |   |   |   |   |   |--- feature_10 <= 0.44
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_10 >  0.44
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_3 >  -1.28
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_8 >  1.41
# |   |   |   |   |   |   |--- feature_9 <= 0.12
# |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_9 >  0.12
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |--- feature_11 >  0.04
# |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |--- feature_10 >  0.59
# |   |   |   |   |--- class: Existing Customer
# |   |--- feature_9 >  0.57
# |   |   |--- feature_10 <= 1.15
# |   |   |   |--- feature_6 <= -0.59
# |   |   |   |   |--- class: Existing Customer
# |   |   |   |--- feature_6 >  -0.59
# |   |   |   |   |--- feature_7 <= -0.37
# |   |   |   |   |   |--- feature_8 <= 0.16
# |   |   |   |   |   |   |--- feature_10 <= 0.73
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_10 >  0.73
# |   |   |   |   |   |   |   |--- feature_26 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.26
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.26
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_26 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1.64
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_9 >  1.64
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |--- feature_8 >  0.16
# |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |--- feature_7 >  -0.37
# |   |   |   |   |   |--- feature_10 <= 0.82
# |   |   |   |   |   |   |--- feature_9 <= 0.74
# |   |   |   |   |   |   |   |--- feature_8 <= 0.97
# |   |   |   |   |   |   |   |   |--- feature_9 <= 0.60
# |   |   |   |   |   |   |   |   |   |--- feature_22 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_22 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_9 >  0.60
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_8 >  0.97
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_9 >  0.74
# |   |   |   |   |   |   |   |--- feature_10 <= 0.59
# |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_10 >  0.59
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1.52
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.43
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.43
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_9 >  1.52
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1.84
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1.84
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_10 >  0.82
# |   |   |   |   |   |   |--- feature_9 <= 1.94
# |   |   |   |   |   |   |   |--- feature_8 <= 0.57
# |   |   |   |   |   |   |   |   |--- feature_11 <= 1.21
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_11 >  1.21
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_8 >  0.57
# |   |   |   |   |   |   |   |   |--- feature_14 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |--- feature_14 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 1.05
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  1.05
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_9 >  1.94
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |--- feature_10 >  1.15
# |   |   |   |--- feature_10 <= 1.61
# |   |   |   |   |--- feature_11 <= 0.62
# |   |   |   |   |   |--- feature_9 <= 1.86
# |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_9 >  1.86
# |   |   |   |   |   |   |--- feature_10 <= 1.33
# |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |--- feature_10 >  1.33
# |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |--- feature_11 >  0.62
# |   |   |   |   |   |--- feature_9 <= 1.38
# |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |--- feature_9 >  1.38
# |   |   |   |   |   |   |--- feature_8 <= -0.02
# |   |   |   |   |   |   |   |--- feature_7 <= -0.67
# |   |   |   |   |   |   |   |   |--- feature_6 <= -0.33
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_6 >  -0.33
# |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |--- feature_7 >  -0.67
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |--- feature_8 >  -0.02
# |   |   |   |   |   |   |   |--- feature_9 <= 3.16
# |   |   |   |   |   |   |   |   |--- feature_12 <= 0.39
# |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |   |--- feature_12 >  0.39
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1.84
# |   |   |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  1.84
# |   |   |   |   |   |   |   |   |   |   |--- class: Attrited Customer
# |   |   |   |   |   |   |   |--- feature_9 >  3.16
# |   |   |   |   |   |   |   |   |--- class: Existing Customer
# |   |   |   |--- feature_10 >  1.61
# |   |   |   |   |--- class: Existing Customer

# %%
with open("decistion_tree.log", "w") as fout:
    fout.write(text_representation)

# %% [markdown]
# Plot Tree with plot_tree

# %%
fig = plt.figure(figsize=(45,40))
_ = tree.plot_tree(dt_clf, feature_names=result_df.columns, filled=True)

# %%
fig.savefig("decistion_tree.png")

# %% [markdown]
# Visualize Decision Tree with graphviz

# %%
result_df.drop(columns=['Marital_Status_Unknown', 'Education_Level_Unknown'], axis=1, inplace=True)

# %%
import graphviz
# DOT data
dot_data = tree.export_graphviz(dt_clf, feature_names=result_df.columns, 
                                class_names=["Attrited Customer", "Existing Customer"], out_file=None, filled=True)

# Drow graph
graph = graphviz.Source(dot_data, format="png")
graph

# %%
graph.render("decision_tree_grphviz")
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.896302 to fit
# 'decision_tree_grphviz.png'

# %%
# Make predictions
y_pred = dt_clf.predict(X_test_processed)

# Evaluate the model
print(round(dt_clf.score(X_test_processed, y_test),2))

# Confusion matrix
confusion_matrix(y_test, y_pred)
crosstab = pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames =['Predicted'], margins = True)
display(crosstab)

# Generate classification report
report = classification_report(y_test, y_pred, zero_division=1)
print(f"Classification Report:\n{classification_report(y_test, y_pred, zero_division=1)}")
# Out:
# 0.95
# Predicted          Attrited Customer  Existing Customer   All
# Actual
# Attrited Customer               2016                 78  2094
# Existing Customer                118               1970  2088
# All                             2134               2048  4182
# Classification Report:
#                    precision    recall  f1-score   support
#
# Attrited Customer       0.94      0.96      0.95      2094
# Existing Customer       0.96      0.94      0.95      2088
#
#          accuracy                           0.95      4182
#         macro avg       0.95      0.95      0.95      4182
#      weighted avg       0.95      0.95      0.95      4182
